# %%
import pickle

# Load the pickle file
file_path = 'image_info_exp4_all_results.pickle'
with open(file_path, 'rb') as f:
    data = pickle.load(f)

# Analyze the loaded data
# Depending on the content and structure of your pickle file, you might need to explore its keys, values, or attributes.
# For example, you might try printing the keys of the loaded dictionary:
if isinstance(data, dict):
    print("Keys in the pickle file:", data.keys())
else:
    print("Loaded data is not a dictionary.")
# Out:
# Keys in the pickle file: dict_keys(['A1-', 'A2-', 'A3-', 'A4-', 'A5-', 'A6-', 'A7-', 'A8-', 'A9-', 'A10-', 'A11-', 'A12-', 'B1-', 'B2-', 'B3-', 'B4-', 'B5-', 'B6-', 'B7-', 'B8-', 'B9-', 'B10-', 'B11-', 'B12-', 'C1-', 'C2-', 'C3-', 'C4-', 'C5-', 'C6-', 'C7-', 'C8-', 'C9-', 'C10-', 'C11-', 'C12-', 'D1-', 'D2-', 'D3-', 'D4-', 'D5-', 'D6-', 'D7-', 'D8-', 'D9-', 'D10-', 'D11-', 'D12-', 'E1-', 'E2-', 'E3-', 'E4-', 'E5-', 'E6-', 'E7-', 'E8-', 'E9-', 'E10-', 'E11-', 'E12-', 'F1-', 'F2-', 'F3-', 'F4-', 'F5-', 'F6-', 'F7-', 'F8-', 'F9-', 'F10-', 'F11-', 'F12-', 'G1-', 'G2-', 'G3-', 'G4-', 'G5-', 'G6-', 'G7-', 'G8-', 'G9-', 'G10-', 'G11-', 'G12-', 'H1-', 'H2-', 'H3-', 'H4-', 'H5-', 'H6-', 'H7-', 'H8-', 'H9-', 'H10-', 'H11-', 'H12-'])

# %%
data_g6 = data['G6-']

# %%
# Printing keys that contain '940' in their names
keys_with_940 = [key for key in data_g6.keys() if '940' in key]
print(keys_with_940)
# Out:
# ['R_01_1107_940_G6-1-green_analyzed.tif', 'R_01_1407_940_G6-1-green_analyzed.tif', 'R_01_1707_940_G6-1-green_analyzed.tif', 'R_01_2007_940_G6-1-green_analyzed.tif', 'R_01_2307_940_G6-1-green_analyzed.tif', 'R_02_0207_940_G6-1-green_analyzed.tif', 'R_02_0507_940_G6-1-green_analyzed.tif', 'R_02_0807_940_G6-1-green_analyzed.tif', 'R_02_1107_940_G6-1-green_analyzed.tif', 'R_02_1407_940_G6-1-green_analyzed.tif', 'R_02_1707_940_G6-1-green_analyzed.tif']

# %%
x_for_plot_940 = ["01_1107", "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                 "02_1707"]

# %%
import matplotlib.pyplot as plt

# %%
# Assuming 'data' contains the loaded pickle file data
data_g6 = data.get('G6-', {})

# Initialize variables to store total areas
total_areas = {}

# Iterate through each image in the 'G6-' key
for image_name, properties in data_g6.items():
    if '940' in image_name:  # Check for '940' in the image name
        split_name = image_name.split('_')
        day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
        area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

        # Store the total area for each day-time point
        if day_time not in total_areas:
            total_areas[day_time] = 0
        total_areas[day_time] += area

# Define x-axis points from the given list
x_for_plot_940 = ["01_1107", "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]

# Extract areas for the given day-time points
area_vals = [total_areas[day_time] for day_time in x_for_plot_940]

# Plotting total area versus day-time points
plt.plot(x_for_plot_940, area_vals)
plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points for LY6E')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
print(area_vals)
# Out:
# [4710, 6050, 7268, 8326, 9008, 9868, 10375, 10702, 11308, 11580, 11587]

# %%
data_h12 = data['H12-']

# ... [Previous code remains the same up to this point] ...

# Similar process for 'H12-' data
day_time_points_h12 = {}
total_areas_h12 = {}

for image_name, properties in data_h12.items():
    if '940' in image_name:
        split_name = image_name.split('_')
        day_time = split_name[1] + '_' + split_name[2]
        area = sum(info['area'] for _, info in properties.items())

        if day_time not in total_areas_h12:
            total_areas_h12[day_time] = 0
        total_areas_h12[day_time] += area
print(total_areas_h12)
# Define x-axis points from the given list
xh12_for_plot_940 = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]

area_vals_h12 = [total_areas_h12[day_time_h12] for day_time_h12 in xh12_for_plot_940]

# Plotting total area versus day-time points for 'A1-' and 'H12-'
plt.plot(x_for_plot_940, area_vals, label='LY6E')
plt.plot(xh12_for_plot_940, area_vals_h12, label='-IFNa')
plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs -IFNa)')
plt.xticks(rotation=45)
plt.legend()  # Show legend to differentiate between 'A1-' and 'H12-'
plt.tight_layout()
plt.show()
# Out:
# {'01_1407': 3830, '01_1707': 4169, '01_2007': 4431, '01_2307': 4614, '02_0207': 4753, '02_0507': 4873, '02_0807': 4979, '02_1107': 5022, '02_1407': 5116, '02_1707': 5218}

# %%
##Cleaner for the thesis:

import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

key_legend_mapping = {
    'H7-': 'NTC1',
    'H8-': 'NTC2',
    'H9-': 'NTC3',
    'H10-': 'NTC4',
    'H11-': 'NTC5',
    'H12-': '-IFNa',
    'D12-': 'IFITM1',
    'E1-': 'IFITM2',
    'E2-': 'IFITM3',
    'D7-': 'IFIH1',
    'G6-': 'LY6E',
    'E11-':'IRF1'
}


# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'H7-', 'H8-', 'H9-', 'H10-', 'H11-', 'E11-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        mapped_label = key_legend_mapping[key]  # Get the mapped label from the dictionary
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=mapped_label)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs IRF1)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_IRF1.png', bbox_inches='tight')
plt.show()

# %%
##Cleaner for the thesis: 938, A6, STAT2

import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

key_legend_mapping = {
    'H7-': 'NTC1',
    'H8-': 'NTC2',
    'H9-': 'NTC3',
    'H10-': 'NTC4',
    'H11-': 'NTC5',
    'H12-': '-IFNa',
    'D12-': 'IFITM1',
    'G6-': 'LY6E',
    'A6-':'STAT2'
}


# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}



custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Extract all keys except 'G6-' and 'A6-'
keys_938 = ['H7-', 'H8-', 'H9-', 'H10-', 'H11-', 'H12-', 'A6-']

# Initialize a dictionary to store total areas for keys from 938 and G6 from 940
total_areas_938 = {}
total_areas_940_g6 = {}

# Define x-axis points from the given list for 940
x_for_plot_940_g6 = ["01_1407", "01_1707", "01_2007", "01_2307",
                      "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                      "02_1707"]

x_for_plot_938 = ["01_1351","01_1651", "01_1951", "01_2251", "02_0151", "02_0451", "02_0751", "02_1051", "02_1351", "02_1651"]
custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

for key in keys_938:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '938' in image_name:  # Check for '938' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area
            #print(day_time)
            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_938[key] = total_areas

# Retrieve LY6E (G6-) data from 940
for image_name, properties in data['G6-'].items():
    if '940' in image_name:  # Check for '940' in the image name
        split_name = image_name.split('_')
        day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
        area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

        # Store the total area for each day-time point for LY6E (G6-)
        if day_time not in total_areas_940_g6:
            total_areas_940_g6[day_time] = 0
        total_areas_940_g6[day_time] += area

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure

# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)

# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'H7-', 'H8-', 'H9-', 'H10-', 'H11-', 'A6-', 'H12-']  # Replace with your desired keys

# Plot data from 938 keys
for key, total_areas in total_areas_938.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_938]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        mapped_label = key_legend_mapping[key]  # Get the mapped label from the dictionary
        plt.plot(range(len(x_for_plot_938)), area_vals, label=mapped_label)

# Plot data for LY6E (G6-) from 940
area_vals_940_g6 = [total_areas_940_g6[day_time] if day_time in total_areas_940_g6 else 0 for day_time in x_for_plot_940_g6]
plt.plot(range(len(x_for_plot_940_g6)), area_vals_940_g6, label=key_legend_mapping['G6-'])  # LY6E (G6-)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs STAT2)')
plt.xticks(range(len(x_for_plot_940_g6)), x_for_plot_940_g6, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_STAT2.png', bbox_inches='tight')
plt.show()

# %%
##Cleaner for the thesis: 941, B6, OAS3

import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

key_legend_mapping = {
    'H7-': 'NTC1',
    'H8-': 'NTC2',
    'H9-': 'NTC3',
    'H10-': 'NTC4',
    'H11-': 'NTC5',
    'H12-': '-IFNa',
    'D12-': 'IFITM1',
    'G6-': 'LY6E',
    'B6-':'OAS3'
}


# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}



custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Extract all keys except 'G6-' and 'A6-'
keys_938 = ['H7-', 'H8-', 'H9-', 'H10-', 'H11-', 'H12-', 'B6-']

# Initialize a dictionary to store total areas for keys from 938 and G6 from 940
total_areas_938 = {}
total_areas_940_g6 = {}

# Define x-axis points from the given list for 940
x_for_plot_940_g6 = ["01_1407", "01_1707", "01_2007", "01_2307",
                      "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                      "02_1707"]

x_for_plot_938 = ["01_1107", "01_1407", "01_1707", "01_2007", "01_2307", "02_0207", "02_0507", "02_0807", "02_1107","02_1407",
"02_1707"]
custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

for key in keys_938:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '941' in image_name:  # Check for '938' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area
            #print(day_time)
            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_938[key] = total_areas

# Retrieve LY6E (G6-) data from 940
for image_name, properties in data['G6-'].items():
    if '940' in image_name:  # Check for '940' in the image name
        split_name = image_name.split('_')
        day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
        area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

        # Store the total area for each day-time point for LY6E (G6-)
        if day_time not in total_areas_940_g6:
            total_areas_940_g6[day_time] = 0
        total_areas_940_g6[day_time] += area

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure

# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)

# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'H7-', 'H8-', 'H9-', 'H10-', 'H11-', 'B6-', 'H12-']  # Replace with your desired keys

# Plot data from 938 keys
for key, total_areas in total_areas_938.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_938]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        mapped_label = key_legend_mapping[key]  # Get the mapped label from the dictionary
        plt.plot(range(len(x_for_plot_938)), area_vals, label=mapped_label)

# Plot data for LY6E (G6-) from 940
area_vals_940_g6 = [total_areas_940_g6[day_time] if day_time in total_areas_940_g6 else 0 for day_time in x_for_plot_940_g6]
plt.plot(range(len(x_for_plot_940_g6)), area_vals_940_g6, label=key_legend_mapping['G6-'])  # LY6E (G6-)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs OAS3)')
plt.xticks(range(len(x_for_plot_940_g6)), x_for_plot_940_g6, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_OAS3.png', bbox_inches='tight')
plt.show()

# %%
# Assuming 'data' contains the loaded pickle file data

key_legend_mapping = {
    'H7-': 'NTC1',
    'H8-': 'NTC2',
    'H9-': 'NTC3',
    'H10-': 'NTC4',
    'H11-': 'NTC5',
    'H12-': '-IFNa',
    'D12-': 'IFITM1',
    'E1-': 'IFITM2',
    'E2-': 'IFITM3',
    'D7-': 'IFIH1',
    'G6-': 'LY6E'
}


# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'H7-', 'H8-', 'H9-', 'H10-', 'H11-','E1-','H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        mapped_label = key_legend_mapping[key]  # Get the mapped label from the dictionary
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=mapped_label)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs IFITM2)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_IFITM2.png', bbox_inches='tight')
plt.show()

# %%
# Assuming 'data' contains the loaded pickle file data

key_legend_mapping = {
    'H7-': 'NTC1',
    'H8-': 'NTC2',
    'H9-': 'NTC3',
    'H10-': 'NTC4',
    'H11-': 'NTC5',
    'H12-': '-IFNa',
    'D12-': 'IFITM1',
    'E1-': 'IFITM2',
    'E2-': 'IFITM3',
    'D7-': 'IFIH1',
    'G6-': 'LY6E'
}


# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'H7-', 'H8-', 'H9-', 'H10-', 'H11-','E2-','H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        mapped_label = key_legend_mapping[key]  # Get the mapped label from the dictionary
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=mapped_label)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs IFITM3)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_IFITM3.png', bbox_inches='tight')
plt.show()

# %%
# Assuming 'data' contains the loaded pickle file data

key_legend_mapping = {
    'H7-': 'NTC1',
    'H8-': 'NTC2',
    'H9-': 'NTC3',
    'H10-': 'NTC4',
    'H11-': 'NTC5',
    'H12-': '-IFNa',
    'D12-': 'IFITM1',
    'E1-': 'IFITM2',
    'E2-': 'IFITM3',
    'D7-': 'IFIH1',
    'G6-': 'LY6E'
}


# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'H7-', 'H8-', 'H9-', 'H10-', 'H11-','D7-','H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        mapped_label = key_legend_mapping[key]  # Get the mapped label from the dictionary
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=mapped_label)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs IFIH1)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_IFIH1.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'A1-', 'A2-', 'A3-', 'A4-', 'A5-', 'A6-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_a1-a6.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'B1-', 'B2-', 'B3-', 'B4-', 'B5-', 'B6-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_b1-b6.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'C1-', 'C2-', 'C3-', 'C4-', 'C5-', 'C6-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_c1-c6.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'D1-', 'D2-', 'D3-', 'D4-', 'D5-', 'D6-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_d1-d6.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'E1-', 'E2-', 'E3-', 'E4-', 'E5-', 'E6-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_e1-e6.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'F1-', 'F2-', 'F3-', 'F4-', 'F5-', 'F6-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_f1-f6.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G1-', 'G2-', 'G3-', 'G4-', 'G5-', 'G6-', 'G7-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_g1-g7.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'H1-', 'H2-', 'H3-', 'H4-', 'H5-', 'H6-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_h1-h6.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'A7-', 'A8-', 'A9-', 'A10-', 'A11-', 'A12-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_a7-a12.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'B7-', 'B8-', 'B9-', 'B10-', 'B11-', 'B12-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_b7-b12.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'C7-', 'C8-', 'C9-', 'C10-', 'C11-', 'C12-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_c7-c12.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'D7-', 'D8-', 'D9-', 'D10-', 'D11-', 'D12-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_d7-d12.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'E7-', 'E8-', 'E9-', 'E10-', 'E11-', 'E12-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_e7-e12.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'F7-', 'F8-', 'F9-', 'F10-', 'F11-', 'F12-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_f7-f12.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'G7-', 'G8-', 'G9-', 'G10-', 'G11-', 'G12-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_g6-g12.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'data' contains the loaded pickle file data

# Extract all keys except 'G6-'
all_keys = [key for key in data.keys()]

# Initialize a dictionary to store total areas for each key
total_areas_dict = {key: {} for key in all_keys}

# Define x-axis points from the given list
x_for_plot_940_all = [ "01_1407", "01_1707", "01_2007", "01_2307",
                  "02_0207", "02_0507", "02_0807", "02_1107", "02_1407",
                  "02_1707"]


custom_colors = ['red', 'green', 'blue', 'orange', 'purple', 'yellow', 'black', 'gray']

# Iterate through each key and calculate total areas
for key in all_keys:
    total_areas = {}
    for image_name, properties in data[key].items():
        if '940' in image_name:  # Check for '940' in the image name
            split_name = image_name.split('_')
            day_time = split_name[1] + '_' + split_name[2]  # Extract day and time
            area = sum(info['area'] for _, info in properties.items())  # Calculate the total area

            # Store the total area for each day-time point for the current key
            if day_time not in total_areas:
                total_areas[day_time] = 0
            total_areas[day_time] += area
    total_areas_dict[key] = total_areas

# Plotting total area versus day-time points for each key separately
plt.figure(figsize=(10, 6))  # Create a figure
# Use the 'Set2' colormap for color cycle
#plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Set2.colors)
# Set the custom color cycle
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=custom_colors)


# Define a list of keys for which you want to show legends
keys_to_show_legends = ['G6-', 'H7-', 'H8-', 'H9-', 'H10-', 'H11-', 'H12-']  # Replace with your desired keys

for key, total_areas in total_areas_dict.items():
    area_vals = [total_areas[day_time] if day_time in total_areas else 0 for day_time in x_for_plot_940_all]
    
    # Only plot and label the keys that are in the 'keys_to_show_legends' list
    if key in keys_to_show_legends:
        plt.plot(range(len(x_for_plot_940_all)), area_vals, label=key)

plt.xlabel('Day-Time Points')
plt.ylabel('Total Area')
plt.title('Total Area vs Day-Time Points (LY6E vs All Others)')
plt.xticks(range(len(x_for_plot_940_all)), x_for_plot_940_all, rotation=45)

# Show legend only for the selected keys
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig('total_area_plot_h7-h12.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ['A1-', 'A2-', 'A3-', 'A4-', 'A5-', 'A6-', 'A7-', 'A8-', 'A9-', 'A10-', 'A11-', 'A12-', 'B1-', 'B2-', 'B3-', 'B4-', 'B5-', 'B6-', 'B7-', 'B8-', 'B9-', 'B10-', 'B11-', 'B12-', 'C1-', 'C2-', 'C3-', 'C4-', 'C5-', 'C6-', 'C7-', 'C8-', 'C9-', 'C10-', 'C11-', 'C12-', 'D1-', 'D2-', 'D3-', 'D4-', 'D5-', 'D6-', 'D7-', 'D8-', 'D9-', 'D10-', 'D11-', 'D12-', 'E1-', 'E2-', 'E3-', 'E4-', 'E5-', 'E6-', 'E7-', 'E8-', 'E9-', 'E10-', 'E11-', 'E12-', 'F1-', 'F2-', 'F3-', 'F4-', 'F5-', 'F6-', 'F7-', 'F8-', 'F9-', 'F10-', 'F11-', 'F12-', 'G1-', 'G2-', 'G3-', 'G4-', 'G5-', 'G6-', 'G7-', 'G8-', 'G9-', 'G10-', 'G11-', 'G12-', 'H1-', 'H2-', 'H3-', 'H4-', 'H5-', 'H6-', 'H7-', 'H8-', 'H9-', 'H10-', 'H11-', 'H12-']
